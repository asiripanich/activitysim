# %%
import pandas as pd
import requests
from io import StringIO
from skimpy import skim 
import numpy as np
import larch.numba as lx
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/actsim-melb/lib/python3.9/site-packages/larch/numba/model.py:23: UserWarning:
#
# ### larch.numba is experimental, and not feature-complete ###
#  the first time you import on a new system, this package will
#  compile optimized binaries for your machine, which may take
#  a little while, please be patient
#
#   warnings.warn( ### EXPERIMENTAL ### )
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ## Download or view input data files
#
# All files are publicly shared at [here](https://unsw-my.sharepoint.com/:f:/g/personal/z5005182_ad_unsw_edu_au/ElRRKDgPUXVOrvhpTrSNfPkBql9AAmqobMmBPgLsx8EIYQ?e=B14TfJ).
#
# Note that, OneDrive doesn't provide shared links that can directly download shared files. The trick is to replace the last part after `?` with `download=1`.

# %%
def read_csv_from_url(url):
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
    req = requests.get(url, headers=headers)
    data = StringIO(req.text)
    data_csv = pd.read_csv(data)
    return(data_csv)

households = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/EV8Hfp8JZypHlH71GnehJaUBtuY4UT-V7GKVB3u4cU0pXw?download=1")
persons = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/EbWPSMy15FdOs_ZemaVELN0B6OXFGVpE9oOuYNNTEcaPJg?download=1")
trips = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/EVrMgQU9fIdJv3-Mzf3grQUBPYy9U3BReZ_WYVTnGLZroQ?download=1")
# Out:
# /var/folders/0r/_nfqg0v10sq4lf56q9dr_pz80000gn/T/ipykernel_53302/3786853629.py:5: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_csv = pd.read_csv(data)
# /var/folders/0r/_nfqg0v10sq4lf56q9dr_pz80000gn/T/ipykernel_53302/3786853629.py:5: DtypeWarning: Columns (12,23,27,41,42,43,84,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_csv = pd.read_csv(data)

# %%
households = households.rename(columns=str.lower)
persons = persons.rename(columns=str.lower)
trips = trips.rename(columns=str.lower)

# %%
bins = [0, 1, 2, 3, float('inf')]
names = ['0', '1', '2', '3+']
households['cars_cat'] = pd.cut(households.cars, bins, labels=names, include_lowest=True, right=False)
households.statistics()
# Out:
#                         n       minimum       maximum        median  \
# hhid                18152           NaN           NaN           NaN
# sampleregion        18152           NaN           NaN           NaN
# week                18152  0.000000e+00  2.080000e+02  1.050000e+02
# hhsize              18152  1.000000e+00  9.000000e+00  2.000000e+00
# visitors            18152  0.000000e+00  1.200000e+01  0.000000e+00
# dwelltype           18152           NaN           NaN           NaN
# owndwell            18152           NaN           NaN           NaN
# yearslived          18152  0.000000e+00  8.800000e+01  8.000000e+00
# monthslived         18152  0.000000e+00  1.300000e+01  4.000000e+00
# adultbikes          18152  0.000000e+00  1.500000e+01  0.000000e+00
# kidsbikes           18152  0.000000e+00  1.100000e+01  0.000000e+00
# totalbikes          18152  0.000000e+00  1.500000e+01  1.000000e+00
# phone               18152           NaN           NaN           NaN
# cars                18152  0.000000e+00  8.000000e+00  1.000000e+00
# fourwds             18152  0.000000e+00  5.000000e+00  0.000000e+00
# utes                18152  0.000000e+00  4.000000e+00  0.000000e+00
# vans                18152  0.000000e+00  2.000000e+00  0.000000e+00
# trucks              18152  0.000000e+00  4.000000e+00  0.000000e+00
# mbikes              18152  0.000000e+00  3.000000e+00  0.000000e+00
# othervehs           18152  0.000000e+00  1.000000e+00  0.000000e+00
# totalvehs           18152  0.000000e+00  9.000000e+00  2.000000e+00
# travdate            18152           NaN           NaN           NaN
# travmonth           18152           NaN           NaN           NaN
# travyear            18152  2.012000e+03  2.016000e+03  2.014000e+03
# travdow             18152           NaN           NaN           NaN
# homepc              18152  3.002000e+03  3.981000e+03  3.146000e+03
# hometaz             18152  2.400000e+01  2.890000e+03  1.069000e+03
# homesla             18152           NaN           NaN           NaN
# homelga             18152           NaN           NaN           NaN
# youngest            18152  0.000000e+00  1.927000e+03  3.200000e+01
# aveage              18152  2.000000e+00  1.928000e+03  4.100000e+01
# oldest              18152  1.000000e+00  1.929000e+03  5.400000e+01
# hhinc               18152           NaN           NaN           NaN
# homesa1             18152  2.030110e+10  2.140214e+10  2.100312e+10
# homesa2             18152           NaN           NaN           NaN
# homesa3             18152           NaN           NaN           NaN
# homesa4             18152           NaN           NaN           NaN
# homeregion_asgs     18152           NaN           NaN           NaN
# homesubregion_asgs  18152           NaN           NaN           NaN
# homeregion_asgc     18152           NaN           NaN           NaN
# cw_adhhwgt_sa3      18152  4.223000e+01  5.488200e+02  9.340000e+01
# cw_wdhhwgt_sa3      18152           NaN           NaN           NaN
# cw_wehhwgt_sa3      18152           NaN           NaN           NaN
# cw_adhhwgt_lga      18152           NaN           NaN           NaN
# cw_wdhhwgt_lga      18152           NaN           NaN           NaN
# cw_wehhwgt_lga      18152           NaN           NaN           NaN
# reportingperiod     18152           NaN           NaN           NaN
# rp_adhhwgt_sa3      18152  6.270000e+01  1.164350e+03  1.838100e+02
# rp_wdhhwgt_sa3      18152           NaN           NaN           NaN
# rp_wehhwgt_sa3      18152           NaN           NaN           NaN
# rp_adhhwgt_lga      18152           NaN           NaN           NaN
# rp_wdhhwgt_lga      18152           NaN           NaN           NaN
# rp_wehhwgt_lga      18152           NaN           NaN           NaN
# cars_cat            18152           NaN           NaN           NaN
#
#                                                             histogram  \
# hhid                                                              NaN
# sampleregion                                                      NaN
# week                [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# hhsize              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# visitors                                                         None
# dwelltype                                                         NaN
# owndwell                                                          NaN
# yearslived          [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# monthslived         [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# adultbikes                                                       None
# kidsbikes                                                        None
# totalbikes                                                       None
# phone                                                             NaN
# cars                [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# fourwds                                                          None
# utes                [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# vans                [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# trucks              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# mbikes              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# othervehs           [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# totalvehs           [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# travdate                                                          NaN
# travmonth                                                         NaN
# travyear            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# travdow                                                           NaN
# homepc              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# hometaz             [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# homesla                                                           NaN
# homelga                                                           NaN
# youngest            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# aveage              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# oldest              [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# hhinc                                                             NaN
# homesa1             [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# homesa2                                                           NaN
# homesa3                                                           NaN
# homesa4                                                           NaN
# homeregion_asgs                                                   NaN
# homesubregion_asgs                                                NaN
# homeregion_asgc                                                   NaN
# cw_adhhwgt_sa3      [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# cw_wdhhwgt_sa3                                                    NaN
# cw_wehhwgt_sa3                                                    NaN
# cw_adhhwgt_lga                                                    NaN
# cw_wdhhwgt_lga                                                    NaN
# cw_wehhwgt_lga                                                    NaN
# reportingperiod                                                   NaN
# rp_adhhwgt_sa3      [[[<Element '{http://www.w3.org/1999/02/22-rdf...
# rp_wdhhwgt_sa3                                                    NaN
# rp_wehhwgt_sa3                                                    NaN
# rp_adhhwgt_lga                                                    NaN
# rp_wdhhwgt_lga                                                    NaN
# rp_wehhwgt_lga                                                    NaN
# cars_cat            [[[<Element '{http://www.w3.org/1999/02/22-rdf...
#
#                             mean         stdev    zeros  positives  negatives  \
# hhid                         NaN           NaN      NaN        NaN        NaN
# sampleregion                 NaN           NaN      NaN        NaN        NaN
# week                1.050468e+02  5.973015e+01     91.0    18061.0        0.0
# hhsize              2.565117e+00  1.314165e+00      0.0    18152.0        0.0
# visitors            2.539665e-01  8.161551e-01  15860.0     2292.0        0.0
# dwelltype                    NaN           NaN      NaN        NaN        NaN
# owndwell                     NaN           NaN      NaN        NaN        NaN
# yearslived          1.260901e+01  1.309097e+01   1632.0    16520.0        0.0
# monthslived         4.370372e+00  2.856269e+00   2281.0    15871.0        0.0
# adultbikes          9.352688e-01  1.262420e+00   9487.0     8665.0        0.0
# kidsbikes           4.148854e-01  9.055342e-01  14138.0     4014.0        0.0
# totalbikes          1.350154e+00  1.709745e+00   8352.0     9800.0        0.0
# phone                        NaN           NaN      NaN        NaN        NaN
# cars                1.299691e+00  8.909737e-01   2885.0    15267.0        0.0
# fourwds             2.814015e-01  5.241313e-01  13659.0     4493.0        0.0
# utes                7.899956e-02  2.873408e-01  16800.0     1352.0        0.0
# vans                1.118334e-02  1.092690e-01  17957.0      195.0        0.0
# trucks              5.784487e-03  8.211366e-02  18053.0       99.0        0.0
# mbikes              4.120758e-02  2.348514e-01  17524.0      628.0        0.0
# othervehs           1.652710e-03  4.061993e-02  18122.0       30.0        0.0
# totalvehs           1.728184e+00  9.845899e-01   1180.0    16972.0        0.0
# travdate                     NaN           NaN      NaN        NaN        NaN
# travmonth                    NaN           NaN      NaN        NaN        NaN
# travyear            2.014077e+03  1.213507e+00      0.0    18152.0        0.0
# travdow                      NaN           NaN      NaN        NaN        NaN
# homepc              3.232852e+03  2.695167e+02      0.0    18152.0        0.0
# hometaz             1.102228e+03  6.394046e+02      0.0    18152.0        0.0
# homesla                      NaN           NaN      NaN        NaN        NaN
# homelga                      NaN           NaN      NaN        NaN        NaN
# youngest            3.642205e+01  2.928576e+01    538.0    17614.0        0.0
# aveage              4.509850e+01  2.505231e+01      0.0    18152.0        0.0
# oldest              5.431093e+01  2.508402e+01      0.0    18152.0        0.0
# hhinc                        NaN           NaN      NaN        NaN        NaN
# homesa1             2.096415e+10  3.078395e+08      0.0    18152.0        0.0
# homesa2                      NaN           NaN      NaN        NaN        NaN
# homesa3                      NaN           NaN      NaN        NaN        NaN
# homesa4                      NaN           NaN      NaN        NaN        NaN
# homeregion_asgs              NaN           NaN      NaN        NaN        NaN
# homesubregion_asgs           NaN           NaN      NaN        NaN        NaN
# homeregion_asgc              NaN           NaN      NaN        NaN        NaN
# cw_adhhwgt_sa3      1.017618e+02  3.794064e+01      0.0    18152.0        0.0
# cw_wdhhwgt_sa3               NaN           NaN      NaN        NaN        NaN
# cw_wehhwgt_sa3               NaN           NaN      NaN        NaN        NaN
# cw_adhhwgt_lga               NaN           NaN      NaN        NaN        NaN
# cw_wdhhwgt_lga               NaN           NaN      NaN        NaN        NaN
# cw_wehhwgt_lga               NaN           NaN      NaN        NaN        NaN
# reportingperiod              NaN           NaN      NaN        NaN        NaN
# rp_adhhwgt_sa3      1.991484e+02  7.541606e+01      0.0    18152.0        0.0
# rp_wdhhwgt_sa3               NaN           NaN      NaN        NaN        NaN
# rp_wehhwgt_sa3               NaN           NaN      NaN        NaN        NaN
# rp_adhhwgt_lga               NaN           NaN      NaN        NaN        NaN
# rp_wdhhwgt_lga               NaN           NaN      NaN        NaN        NaN
# rp_wehhwgt_lga               NaN           NaN      NaN        NaN        NaN
# cars_cat                     NaN           NaN      NaN        NaN        NaN
#
#                     nonzero_minimum  nonzero_maximum  nonzero_mean  \
# hhid                            NaN              NaN           NaN
# sampleregion                    NaN              NaN           NaN
# week                   1.000000e+00     2.080000e+02  1.055761e+02
# hhsize                 1.000000e+00     9.000000e+00  2.565117e+00
# visitors               1.000000e+00     1.200000e+01  2.011344e+00
# dwelltype                       NaN              NaN           NaN
# owndwell                        NaN              NaN           NaN
# yearslived             1.000000e+00     8.800000e+01  1.385465e+01
# monthslived            1.000000e+00     1.300000e+01  4.998488e+00
# adultbikes             1.000000e+00     1.500000e+01  1.959261e+00
# kidsbikes              1.000000e+00     1.100000e+01  1.876183e+00
# totalbikes             1.000000e+00     1.500000e+01  2.500816e+00
# phone                           NaN              NaN           NaN
# cars                   1.000000e+00     8.000000e+00  1.545294e+00
# fourwds                1.000000e+00     5.000000e+00  1.136880e+00
# utes                   1.000000e+00     4.000000e+00  1.060651e+00
# vans                   1.000000e+00     2.000000e+00  1.041026e+00
# trucks                 1.000000e+00     4.000000e+00  1.060606e+00
# mbikes                 1.000000e+00     3.000000e+00  1.191083e+00
# othervehs              1.000000e+00     1.000000e+00  1.000000e+00
# totalvehs              1.000000e+00     9.000000e+00  1.848338e+00
# travdate                        NaN              NaN           NaN
# travmonth                       NaN              NaN           NaN
# travyear               2.012000e+03     2.016000e+03  2.014077e+03
# travdow                         NaN              NaN           NaN
# homepc                 3.002000e+03     3.981000e+03  3.232852e+03
# hometaz                2.400000e+01     2.890000e+03  1.102228e+03
# homesla                         NaN              NaN           NaN
# homelga                         NaN              NaN           NaN
# youngest               1.000000e+00     1.927000e+03  3.753452e+01
# aveage                 2.000000e+00     1.928000e+03  4.509850e+01
# oldest                 1.000000e+00     1.929000e+03  5.431093e+01
# hhinc                           NaN              NaN           NaN
# homesa1                2.030110e+10     2.140214e+10  2.096415e+10
# homesa2                         NaN              NaN           NaN
# homesa3                         NaN              NaN           NaN
# homesa4                         NaN              NaN           NaN
# homeregion_asgs                 NaN              NaN           NaN
# homesubregion_asgs              NaN              NaN           NaN
# homeregion_asgc                 NaN              NaN           NaN
# cw_adhhwgt_sa3         4.223000e+01     5.488200e+02  1.017618e+02
# cw_wdhhwgt_sa3                  NaN              NaN           NaN
# cw_wehhwgt_sa3                  NaN              NaN           NaN
# cw_adhhwgt_lga                  NaN              NaN           NaN
# cw_wdhhwgt_lga                  NaN              NaN           NaN
# cw_wehhwgt_lga                  NaN              NaN           NaN
# reportingperiod                 NaN              NaN           NaN
# rp_adhhwgt_sa3         6.270000e+01     1.164350e+03  1.991484e+02
# rp_wdhhwgt_sa3                  NaN              NaN           NaN
# rp_wehhwgt_sa3                  NaN              NaN           NaN
# rp_adhhwgt_lga                  NaN              NaN           NaN
# rp_wdhhwgt_lga                  NaN              NaN           NaN
# rp_wehhwgt_lga                  NaN              NaN           NaN
# cars_cat                        NaN              NaN           NaN
#
#                     nonzero_stdev  nulls mode
# hhid                          NaN    NaN  NaN
# sampleregion                  NaN    NaN  NaN
# week                 5.941201e+01    NaN  NaN
# hhsize               1.314165e+00    NaN  NaN
# visitors             1.319359e+00    NaN  NaN
# dwelltype                     NaN    NaN  NaN
# owndwell                      NaN    NaN  NaN
# yearslived           1.307844e+01    NaN  NaN
# monthslived          2.488205e+00    NaN  NaN
# adultbikes           1.154265e+00    NaN  NaN
# kidsbikes            9.830987e-01    NaN  NaN
# totalbikes           1.592777e+00    NaN  NaN
# phone                         NaN    NaN  NaN
# cars                 7.512104e-01    NaN  NaN
# fourwds              3.705192e-01    NaN  NaN
# utes                 2.594752e-01    NaN  NaN
# vans                 1.983495e-01    NaN  NaN
# trucks               3.428397e-01    NaN  NaN
# mbikes               4.739555e-01    NaN  NaN
# othervehs            0.000000e+00    NaN  NaN
# totalvehs            9.026248e-01    NaN  NaN
# travdate                      NaN    NaN  NaN
# travmonth                     NaN    NaN  NaN
# travyear             1.213507e+00    NaN  NaN
# travdow                       NaN    NaN  NaN
# homepc               2.695167e+02    NaN  NaN
# hometaz              6.394046e+02    NaN  NaN
# homesla                       NaN    NaN  NaN
# homelga                       NaN    NaN  NaN
# youngest             2.901889e+01    NaN  NaN
# aveage               2.505231e+01    NaN  NaN
# oldest               2.508402e+01    NaN  NaN
# hhinc                         NaN    NaN  NaN
# homesa1              3.078395e+08    NaN  NaN
# homesa2                       NaN    NaN  NaN
# homesa3                       NaN    NaN  NaN
# homesa4                       NaN    NaN  NaN
# homeregion_asgs               NaN    NaN  NaN
# homesubregion_asgs            NaN    NaN  NaN
# homeregion_asgc               NaN    NaN  NaN
# cw_adhhwgt_sa3       3.794064e+01    NaN  NaN
# cw_wdhhwgt_sa3                NaN    NaN  NaN
# cw_wehhwgt_sa3                NaN    NaN  NaN
# cw_adhhwgt_lga                NaN    NaN  NaN
# cw_wdhhwgt_lga                NaN    NaN  NaN
# cw_wehhwgt_lga                NaN    NaN  NaN
# reportingperiod               NaN    NaN  NaN
# rp_adhhwgt_sa3       7.541606e+01    NaN  NaN
# rp_wdhhwgt_sa3                NaN    NaN  NaN
# rp_wehhwgt_sa3                NaN    NaN  NaN
# rp_adhhwgt_lga                NaN    NaN  NaN
# rp_wdhhwgt_lga                NaN    NaN  NaN
# rp_wehhwgt_lga                NaN    NaN  NaN
# cars_cat                      NaN    0.0    1

# %%
households.hhinc
# Out:
# 0        1225
# 1        1700
# 2        1000
# 3        1875
# 4        1750
#          ...
# 18147    1725
# 18148    2500
# 18149    1000
# 18150       0
# 18151     700
# Name: hhinc, Length: 18152, dtype: object

# %%
# prepare choice model data
hhauto = (
    households
        .filter(['hhid', 'cars_cat', 'dwelltype', 'hhsize', 'hhinc', 'owndwell'])
        .assign(
            # integerise household income (hhinc)
            # hhinc = lambda x: x.hhinc,#.str.strip(),#.str.replace('^$', '0'),#.astype(int),
            hhinc = lambda x: np.where(x.hhinc == " ", 0, x.hhinc).astype(int), # TOFIX: " " is missing not 0, the right approach would be to impute the missing hhincome.
            owndwell = lambda x: x.owndwell.astype('category'),
            dwelltype = lambda x: x.dwelltype.astype('category')
        )
)

hhauto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18152 entries, 0 to 18151
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   hhid       18152 non-null  object
#  1   cars_cat   18152 non-null  category
#  2   dwelltype  18152 non-null  category
#  3   hhsize     18152 non-null  int64
#  4   hhinc      18152 non-null  int64
#  5   owndwell   18152 non-null  category
# dtypes: category(3), int64(2), object(1)
# memory usage: 479.3+ KB

# %% [markdown]
# ## Prepare choice data
#
# {larch} requires the choice data to be in a specific format.

# %%
df = (
    hhauto
     .filter(['hhid'])
     .merge(pd.DataFrame({'cars_choice': ['0', '1', '2', '3+']}), how='cross')
     .merge(hhauto, on = ['hhid'])
     .rename(columns={'cars_cat': 'cars'})
     .assign(cars_chosen = lambda x: np.where(x.cars == x.cars_choice, 1, 0))
     .drop(['cars'], axis = 1)
     .assign(hhid = lambda x: x.groupby(['hhid']).ngroup()+1)
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72608 entries, 0 to 72607
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hhid         72608 non-null  int64
#  1   cars_choice  72608 non-null  object
#  2   dwelltype    72608 non-null  category
#  3   hhsize       72608 non-null  int64
#  4   hhinc        72608 non-null  int64
#  5   owndwell     72608 non-null  category
#  6   cars_chosen  72608 non-null  int64
# dtypes: category(2), int64(4), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# Problems to be addressed
# - `alt_codes` and `alt_names` cannot be specified.
# - m.

# %%
d = lx.DataFrames(
    df.set_index(['hhid', 'cars_choice']),
    ch='cars_chosen',
    crack=True,
    # alt_codes=[0,1,2,3],
    # alt_names=['a','b','c'],
    av=True
    # alt_names=['a', 'b', 'c'],
    # alt_codes=[1, 2, 3]
)
d.info(verbose=True)
d.alternative_names()
# Out:
# /var/folders/0r/_nfqg0v10sq4lf56q9dr_pz80000gn/T/ipykernel_53302/2843921929.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d = lx.DataFrames(
# converting data_ch to <class 'numpy.float64'>
# larch.DataFrames:  (not computation-ready)
#   n_cases: 18152
#   n_alts: 4
#   data_ca:
#     - dwelltype   (72608 non-null category)
#     - owndwell    (72608 non-null category)
#     - cars_chosen (72608 non-null int64)
#   data_co:
#     - hhsize (18152 non-null int64)
#     - hhinc  (18152 non-null int64)
#   data_av: <populated>
#   data_ch: cars_chosen
# ['0', '1', '2', '3+']

# %% [markdown]
# ## Estimate a driver's licence status model
#
# Using the persons table and larch, we estimate a MNL model for predicting the probabilities of driver's licence status.

# %%
from larch import P, X, PX

# %%
m = lx.Model(dataservice=d)
m.utility_co[1] = P("ASC_1") + P("hhinc#2") * X("hhinc/1000") + P("hhsize#2") * X("hhsize")
m.utility_co[2] = P("ASC_2") + P("hhinc#3") * X("hhinc/1000") + P("hhsize#3") * X("hhsize")
m.utility_co[3] = P("ASC_3+") + P("hhinc#4") * X("hhinc/1000") + P("hhsize#4") * X("hhsize")
# m.utility_co[4] = P("ASC_4+") + P("hhinc#5") * X("hhinc") + P("hhsize#5") * X("hhsize")
# m.utility_ca = PX("x2")
m.estimate()
m.parameter_summary()
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# <h3>Iteration 011 [Optimization terminated successfully.] </h3>
# <p>Best LL = -20516.214086332875</p>
#              value  initvalue  nullvalue  minimum  maximum  holdfast note  \
# ASC_1     3.613558        0.0        0.0     -inf      inf         0
# ASC_2     4.526842        0.0        0.0     -inf      inf         0
# ASC_3+    2.703109        0.0        0.0     -inf      inf         0
# hhinc#2  -0.277205        0.0        0.0     -inf      inf         0
# hhinc#3  -0.227719        0.0        0.0     -inf      inf         0
# hhinc#4  -0.084652        0.0        0.0     -inf      inf         0
# hhsize#2 -0.835087        0.0        0.0     -inf      inf         0
# hhsize#3 -0.773918        0.0        0.0     -inf      inf         0
# hhsize#4 -0.386212        0.0        0.0     -inf      inf         0
#
#               best
# ASC_1     3.613558
# ASC_2     4.526842
# ASC_3+    2.703109
# hhinc#2  -0.277205
# hhinc#3  -0.227719
# hhinc#4  -0.084652
# hhsize#2 -0.835087
# hhsize#3 -0.773918
# hhsize#4 -0.386212
# <style type="text/css">
# #T_fcb9f th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_fcb9f td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_fcb9f_row0_col0, #T_fcb9f_row0_col1, #T_fcb9f_row0_col2, #T_fcb9f_row0_col3, #T_fcb9f_row0_col4, #T_fcb9f_row1_col0, #T_fcb9f_row1_col1, #T_fcb9f_row1_col2, #T_fcb9f_row1_col3, #T_fcb9f_row1_col4, #T_fcb9f_row2_col0, #T_fcb9f_row2_col1, #T_fcb9f_row2_col2, #T_fcb9f_row2_col3, #T_fcb9f_row2_col4, #T_fcb9f_row3_col0, #T_fcb9f_row3_col1, #T_fcb9f_row3_col2, #T_fcb9f_row3_col3, #T_fcb9f_row3_col4, #T_fcb9f_row4_col0, #T_fcb9f_row4_col1, #T_fcb9f_row4_col2, #T_fcb9f_row4_col3, #T_fcb9f_row4_col4, #T_fcb9f_row5_col0, #T_fcb9f_row5_col1, #T_fcb9f_row5_col2, #T_fcb9f_row5_col3, #T_fcb9f_row5_col4, #T_fcb9f_row6_col0, #T_fcb9f_row6_col1, #T_fcb9f_row6_col2, #T_fcb9f_row6_col3, #T_fcb9f_row6_col4, #T_fcb9f_row7_col0, #T_fcb9f_row7_col1, #T_fcb9f_row7_col2, #T_fcb9f_row7_col3, #T_fcb9f_row7_col4, #T_fcb9f_row8_col0, #T_fcb9f_row8_col1, #T_fcb9f_row8_col2, #T_fcb9f_row8_col3, #T_fcb9f_row8_col4 {
#   font-family: monospace;
# }
# </style>
# <table id="T_fcb9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcb9f_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_fcb9f_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_fcb9f_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_fcb9f_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_fcb9f_level0_col4" class="col_heading level0 col4" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb9f_level0_row0" class="row_heading level0 row0" >ASC_1</th>
#       <td id="T_fcb9f_row0_col0" class="data row0 col0" > 3.61</td>
#       <td id="T_fcb9f_row0_col1" class="data row0 col1" > 0.0936</td>
#       <td id="T_fcb9f_row0_col2" class="data row0 col2" > 38.59</td>
#       <td id="T_fcb9f_row0_col3" class="data row0 col3" >***</td>
#       <td id="T_fcb9f_row0_col4" class="data row0 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row1" class="row_heading level0 row1" >ASC_2</th>
#       <td id="T_fcb9f_row1_col0" class="data row1 col0" > 4.53</td>
#       <td id="T_fcb9f_row1_col1" class="data row1 col1" > 0.0867</td>
#       <td id="T_fcb9f_row1_col2" class="data row1 col2" > 52.21</td>
#       <td id="T_fcb9f_row1_col3" class="data row1 col3" >***</td>
#       <td id="T_fcb9f_row1_col4" class="data row1 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row2" class="row_heading level0 row2" >ASC_3+</th>
#       <td id="T_fcb9f_row2_col0" class="data row2 col0" > 2.70</td>
#       <td id="T_fcb9f_row2_col1" class="data row2 col1" > 0.0877</td>
#       <td id="T_fcb9f_row2_col2" class="data row2 col2" > 30.84</td>
#       <td id="T_fcb9f_row2_col3" class="data row2 col3" >***</td>
#       <td id="T_fcb9f_row2_col4" class="data row2 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row3" class="row_heading level0 row3" >hhinc#2</th>
#       <td id="T_fcb9f_row3_col0" class="data row3 col0" >-0.277</td>
#       <td id="T_fcb9f_row3_col1" class="data row3 col1" > 0.0255</td>
#       <td id="T_fcb9f_row3_col2" class="data row3 col2" >-10.87</td>
#       <td id="T_fcb9f_row3_col3" class="data row3 col3" >***</td>
#       <td id="T_fcb9f_row3_col4" class="data row3 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row4" class="row_heading level0 row4" >hhinc#3</th>
#       <td id="T_fcb9f_row4_col0" class="data row4 col0" >-0.228</td>
#       <td id="T_fcb9f_row4_col1" class="data row4 col1" > 0.0207</td>
#       <td id="T_fcb9f_row4_col2" class="data row4 col2" >-10.98</td>
#       <td id="T_fcb9f_row4_col3" class="data row4 col3" >***</td>
#       <td id="T_fcb9f_row4_col4" class="data row4 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row5" class="row_heading level0 row5" >hhinc#4</th>
#       <td id="T_fcb9f_row5_col0" class="data row5 col0" >-0.0847</td>
#       <td id="T_fcb9f_row5_col1" class="data row5 col1" > 0.0201</td>
#       <td id="T_fcb9f_row5_col2" class="data row5 col2" >-4.21</td>
#       <td id="T_fcb9f_row5_col3" class="data row5 col3" >***</td>
#       <td id="T_fcb9f_row5_col4" class="data row5 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row6" class="row_heading level0 row6" >hhsize#2</th>
#       <td id="T_fcb9f_row6_col0" class="data row6 col0" >-0.835</td>
#       <td id="T_fcb9f_row6_col1" class="data row6 col1" > 0.0278</td>
#       <td id="T_fcb9f_row6_col2" class="data row6 col2" >-30.07</td>
#       <td id="T_fcb9f_row6_col3" class="data row6 col3" >***</td>
#       <td id="T_fcb9f_row6_col4" class="data row6 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row7" class="row_heading level0 row7" >hhsize#3</th>
#       <td id="T_fcb9f_row7_col0" class="data row7 col0" >-0.774</td>
#       <td id="T_fcb9f_row7_col1" class="data row7 col1" > 0.0232</td>
#       <td id="T_fcb9f_row7_col2" class="data row7 col2" >-33.37</td>
#       <td id="T_fcb9f_row7_col3" class="data row7 col3" >***</td>
#       <td id="T_fcb9f_row7_col4" class="data row7 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fcb9f_level0_row8" class="row_heading level0 row8" >hhsize#4</th>
#       <td id="T_fcb9f_row8_col0" class="data row8 col0" >-0.386</td>
#       <td id="T_fcb9f_row8_col1" class="data row8 col1" > 0.0226</td>
#       <td id="T_fcb9f_row8_col2" class="data row8 col2" >-17.08</td>
#       <td id="T_fcb9f_row8_col3" class="data row8 col3" >***</td>
#       <td id="T_fcb9f_row8_col4" class="data row8 col4" > 0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## A minimal example of Larch with on a dummy dataset

# %%
test_df = (pd.DataFrame({
    'caseid': [1, 1, 1, 2, 2, 2],
    'altid': ['a', 'b', 'c', 'a', 'b', 'c'],
    'chose': [1, 0, 0, 0, 1, 0],
    'x1': [500, 500, 500, 2000, 2000, 2000],
    'x2': [123, 322, 435, 123, 435, 234],
    'x_av': [1, 1, 0, 1, 1, 1],
}).assign(altid = lambda x: x.altid.astype('category'))
      )

# test_df.reset_index().info()

# %%
# ds = lx.Dataset.construct.from_idca(test_df.set_index(['caseid', 'altid']))
# m = lx.Model(ds)
# m.choice_ca_code = 'cars_cat'
# ds

d = lx.DataFrames(
    test_df.set_index(['caseid', 'altid']),
    ch='chose',
    crack=True,
    # alt_codes=[1,2,3],
    # alt_names=['a','b','c'],
    av='x_av == 1'
    # alt_names=['a', 'b', 'c'],
    # alt_codes=[1, 2, 3]
)
d.info(verbose=True)
d.alternative_names()
# Out:
# converting data_ch to <class 'numpy.float64'>
# larch.DataFrames:  (not computation-ready)
#   n_cases: 2
#   n_alts: 3
#   data_ca:
#     - chose (6 non-null int64)
#     - x2    (6 non-null int64)
#     - x_av  (6 non-null int64)
#   data_co:
#     - x1 (2 non-null int64)
#   data_av: x_av == 1
#   data_ch: chose
# ['a', 'b', 'c']

# %%
# d.data_co.statistics()
m = lx.Model(dataservice=d)

# %%
from larch import P, X, PX

# %%
m.utility_co[2] = P("ASC_b")  + P("x1#2") * X("x1")
m.utility_co[3] = P("ASC_c") + P("x1#3") * X("x1")
m.utility_ca = PX("x2")
m.estimate()
m.parameter_summary()
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_ca to <class 'numpy.float64'>
# converting data_co to <class 'numpy.float64'>
# <h3>Iteration 019 [Optimization terminated successfully.] </h3>
# <p>Best LL = -2.842170943040401e-14</p>
#                value  initvalue  nullvalue  minimum  maximum  holdfast note  \
# ASC_b       1.320741        0.0        0.0     -inf      inf         0
# ASC_c  455870.090751        0.0        0.0     -inf      inf         0
# x1#2        0.152631        0.0        0.0     -inf      inf         0
# x1#3     -519.650844        0.0        0.0     -inf      inf         0
# x2         -0.883112        0.0        0.0     -inf      inf         0
#
#                 best
# ASC_b       1.320741
# ASC_c  455870.090751
# x1#2        0.152631
# x1#3     -519.650844
# x2         -0.883112
# /opt/homebrew/Caskroom/mambaforge/base/envs/actsim-melb/lib/python3.9/site-packages/larch/linalg/__init__.py:18: UserWarning: minimum eig 0.0 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# <style type="text/css">
# #T_1be8a th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1be8a td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1be8a_row0_col0, #T_1be8a_row0_col1, #T_1be8a_row0_col2, #T_1be8a_row0_col3, #T_1be8a_row0_col4, #T_1be8a_row0_col5, #T_1be8a_row1_col0, #T_1be8a_row1_col1, #T_1be8a_row1_col2, #T_1be8a_row1_col3, #T_1be8a_row1_col4, #T_1be8a_row1_col5, #T_1be8a_row2_col0, #T_1be8a_row2_col1, #T_1be8a_row2_col2, #T_1be8a_row2_col3, #T_1be8a_row2_col4, #T_1be8a_row2_col5, #T_1be8a_row3_col0, #T_1be8a_row3_col1, #T_1be8a_row3_col2, #T_1be8a_row3_col3, #T_1be8a_row3_col4, #T_1be8a_row3_col5, #T_1be8a_row4_col0, #T_1be8a_row4_col1, #T_1be8a_row4_col2, #T_1be8a_row4_col3, #T_1be8a_row4_col4, #T_1be8a_row4_col5 {
#   font-family: monospace;
# }
# </style>
# <table id="T_1be8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1be8a_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_1be8a_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_1be8a_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_1be8a_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_1be8a_level0_col4" class="col_heading level0 col4" >Like Ratio</th>
#       <th id="T_1be8a_level0_col5" class="col_heading level0 col5" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1be8a_level0_row0" class="row_heading level0 row0" >ASC_b</th>
#       <td id="T_1be8a_row0_col0" class="data row0 col0" > 1.32</td>
#       <td id="T_1be8a_row0_col1" class="data row0 col1" > 0.00</td>
#       <td id="T_1be8a_row0_col2" class="data row0 col2" > NA</td>
#       <td id="T_1be8a_row0_col3" class="data row0 col3" >[]</td>
#       <td id="T_1be8a_row0_col4" class="data row0 col4" > 0.00</td>
#       <td id="T_1be8a_row0_col5" class="data row0 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row1" class="row_heading level0 row1" >ASC_c</th>
#       <td id="T_1be8a_row1_col0" class="data row1 col0" > 4.56e+05</td>
#       <td id="T_1be8a_row1_col1" class="data row1 col1" > 0.00</td>
#       <td id="T_1be8a_row1_col2" class="data row1 col2" > NA</td>
#       <td id="T_1be8a_row1_col3" class="data row1 col3" >[]</td>
#       <td id="T_1be8a_row1_col4" class="data row1 col4" > 0.00</td>
#       <td id="T_1be8a_row1_col5" class="data row1 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row2" class="row_heading level0 row2" >x1#2</th>
#       <td id="T_1be8a_row2_col0" class="data row2 col0" > 0.153</td>
#       <td id="T_1be8a_row2_col1" class="data row2 col1" > 0.00</td>
#       <td id="T_1be8a_row2_col2" class="data row2 col2" > NA</td>
#       <td id="T_1be8a_row2_col3" class="data row2 col3" >[***]</td>
#       <td id="T_1be8a_row2_col4" class="data row2 col4" > 274.21</td>
#       <td id="T_1be8a_row2_col5" class="data row2 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row3" class="row_heading level0 row3" >x1#3</th>
#       <td id="T_1be8a_row3_col0" class="data row3 col0" >-520.</td>
#       <td id="T_1be8a_row3_col1" class="data row3 col1" > 0.00</td>
#       <td id="T_1be8a_row3_col2" class="data row3 col2" > NA</td>
#       <td id="T_1be8a_row3_col3" class="data row3 col3" >[***]</td>
#       <td id="T_1be8a_row3_col4" class="data row3 col4" > BIG</td>
#       <td id="T_1be8a_row3_col5" class="data row3 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row4" class="row_heading level0 row4" >x2</th>
#       <td id="T_1be8a_row4_col0" class="data row4 col0" >-0.883</td>
#       <td id="T_1be8a_row4_col1" class="data row4 col1" > 0.00</td>
#       <td id="T_1be8a_row4_col2" class="data row4 col2" > NA</td>
#       <td id="T_1be8a_row4_col3" class="data row4 col3" >[***]</td>
#       <td id="T_1be8a_row4_col4" class="data row4 col4" > 77.64</td>
#       <td id="T_1be8a_row4_col5" class="data row4 col5" > 0.00</td>
#     </tr>
#   </tbody>
# </table>
