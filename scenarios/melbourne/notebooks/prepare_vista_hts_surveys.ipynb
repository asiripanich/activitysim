# %%
import pandas as pd
import requests
from io import StringIO
from skimpy import skim 
import numpy as np
import larch.numba as lx
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/actsim-melb/lib/python3.9/site-packages/larch/numba/model.py:23: UserWarning:
#
# ### larch.numba is experimental, and not feature-complete ###
#  the first time you import on a new system, this package will
#  compile optimized binaries for your machine, which may take
#  a little while, please be patient
#
#   warnings.warn( ### EXPERIMENTAL ### )
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ## Download or view input data files
#
# All files are publicly shared at [here](https://unsw-my.sharepoint.com/:f:/g/personal/z5005182_ad_unsw_edu_au/ElRRKDgPUXVOrvhpTrSNfPkBql9AAmqobMmBPgLsx8EIYQ?e=B14TfJ).
#
# Note that, OneDrive doesn't provide shared links that can directly download shared files. The trick is to replace the last part after `?` with `download=1`.

# %%
def read_csv_from_url(url):
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
    req = requests.get(url, headers=headers)
    data = StringIO(req.text)
    data_csv = pd.read_csv(data)
    return(data_csv)

households = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/EbLQEsk7UelFlyUGMUc2CckBDi3KNC7kW3l6XaNOHmkdaw?download=1")
persons = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/ESa25fnqOWxFmrwN0xNj6sMBMzFjvJM1fTccglqCc_8Dgg?download=1")
trips = read_csv_from_url("https://unsw-my.sharepoint.com/:x:/g/personal/z5005182_ad_unsw_edu_au/EWFMhJS4WtFMvvRMLLCTmDsBA3zYHeOzsGOrfIuePRw9Yg?download=1")
# Out:
# /var/folders/0r/_nfqg0v10sq4lf56q9dr_pz80000gn/T/ipykernel_2413/1110988572.py:5: DtypeWarning: Columns (10,34,35,36,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_csv = pd.read_csv(data)

# %%
households = households.rename(columns=str.lower)
persons = persons.rename(columns=str.lower)
trips = trips.rename(columns=str.lower)

# %%
bins = [0, 1, 2, 3, float('inf')]
names = ['0', '1', '2', '3+']
households['cars_cat'] = pd.cut(households.cars, bins, labels=names, include_lowest=True, right=False)
households.statistics()
# Out:
#                    n  minimum  maximum  median  \
# hhid           25140      NaN      NaN     NaN
# surveyperiod   25140      NaN      NaN     NaN
# travdow        25140      NaN      NaN     NaN
# travmonth      25140      NaN      NaN     NaN
# daytype        25140      NaN      NaN     NaN
# dwelltype      25140      NaN      NaN     NaN
# owndwell       25140      NaN      NaN     NaN
# hhsize         25140      1.0     11.0     2.0
# hhinc          25140      NaN      NaN     NaN
# visitors       25140      0.0     12.0     0.0
# aveage         25140      2.0   1928.0    41.0
# youngest       25140      0.0   1927.0    32.0
# oldest         25140      1.0   1929.0    54.0
# yearslived     25140      0.0     88.0     8.0
# monthslived    25140      0.0     18.0     4.0
# adultbikes     25140      0.0     15.0     0.0
# kidsbikes      25140      0.0     11.0     0.0
# totalbikes     25140      0.0     15.0     1.0
# cars           25140      0.0      8.0     1.0
# fourwds        25140      0.0      5.0     0.0
# utes           25140      0.0      4.0     0.0
# vans           25140      0.0      2.0     0.0
# trucks         25140      0.0      4.0     0.0
# mbikes         25140      0.0      5.0     0.0
# othervehs      25140      0.0      1.0     0.0
# totalvehs      25140      0.0      9.0     2.0
# wdhhwgt        25140      NaN      NaN     NaN
# wehhwgt        25140      NaN      NaN     NaN
# homelga        25140      NaN      NaN     NaN
# homesubregion  25140      NaN      NaN     NaN
# homeregion     25140      NaN      NaN     NaN
# homepc         25140   3002.0   3981.0  3143.5
# cars_cat       25140      NaN      NaN     NaN
#
#                                                        histogram         mean  \
# hhid                                                         NaN          NaN
# surveyperiod                                                 NaN          NaN
# travdow                                                      NaN          NaN
# travmonth                                                    NaN          NaN
# daytype                                                      NaN          NaN
# dwelltype                                                    NaN          NaN
# owndwell                                                     NaN          NaN
# hhsize         [[[<Element '{http://www.w3.org/1999/02/22-rdf...     2.566269
# hhinc                                                        NaN          NaN
# visitors                                                    None     0.247772
# aveage         [[[<Element '{http://www.w3.org/1999/02/22-rdf...    45.383930
# youngest       [[[<Element '{http://www.w3.org/1999/02/22-rdf...    36.511774
# oldest         [[[<Element '{http://www.w3.org/1999/02/22-rdf...    54.539141
# yearslived     [[[<Element '{http://www.w3.org/1999/02/22-rdf...    12.679753
# monthslived    [[[<Element '{http://www.w3.org/1999/02/22-rdf...     4.227168
# adultbikes                                                  None     0.907757
# kidsbikes                                                   None     0.406245
# totalbikes                                                  None     1.314002
# cars           [[[<Element '{http://www.w3.org/1999/02/22-rdf...     1.276253
# fourwds                                                     None     0.295545
# utes           [[[<Element '{http://www.w3.org/1999/02/22-rdf...     0.076134
# vans           [[[<Element '{http://www.w3.org/1999/02/22-rdf...     0.010382
# trucks         [[[<Element '{http://www.w3.org/1999/02/22-rdf...     0.006046
# mbikes         [[[<Element '{http://www.w3.org/1999/02/22-rdf...     0.038902
# othervehs      [[[<Element '{http://www.w3.org/1999/02/22-rdf...     0.001551
# totalvehs      [[[<Element '{http://www.w3.org/1999/02/22-rdf...     1.716667
# wdhhwgt                                                      NaN          NaN
# wehhwgt                                                      NaN          NaN
# homelga                                                      NaN          NaN
# homesubregion                                                NaN          NaN
# homeregion                                                   NaN          NaN
# homepc         [[[<Element '{http://www.w3.org/1999/02/22-rdf...  3230.606523
# cars_cat       [[[<Element '{http://www.w3.org/1999/02/22-rdf...          NaN
#
#                     stdev    zeros  positives  negatives  nonzero_minimum  \
# hhid                  NaN      NaN        NaN        NaN              NaN
# surveyperiod          NaN      NaN        NaN        NaN              NaN
# travdow               NaN      NaN        NaN        NaN              NaN
# travmonth             NaN      NaN        NaN        NaN              NaN
# daytype               NaN      NaN        NaN        NaN              NaN
# dwelltype             NaN      NaN        NaN        NaN              NaN
# owndwell              NaN      NaN        NaN        NaN              NaN
# hhsize           1.323591      0.0    25140.0        0.0              1.0
# hhinc                 NaN      NaN        NaN        NaN              NaN
# visitors         0.804166  22057.0     3083.0        0.0              1.0
# aveage          23.779781      0.0    25140.0        0.0              2.0
# youngest        28.524663    727.0    24413.0        0.0              1.0
# oldest          23.042031      0.0    25140.0        0.0              1.0
# yearslived      13.387399   2435.0    22705.0        0.0              1.0
# monthslived      3.072472   4366.0    20774.0        0.0              1.0
# adultbikes       1.248405  13476.0    11664.0        0.0              1.0
# kidsbikes        0.895361  19657.0     5483.0        0.0              1.0
# totalbikes       1.697268  11897.0    13243.0        0.0              1.0
# cars             0.897190   4306.0    20834.0        0.0              1.0
# fourwds          0.535609  18638.0     6502.0        0.0              1.0
# utes             0.281933  23333.0     1807.0        0.0              1.0
# vans             0.105212  24889.0      251.0        0.0              1.0
# trucks           0.082974  24996.0      144.0        0.0              1.0
# mbikes           0.231727  24325.0      815.0        0.0              1.0
# othervehs        0.039356  25101.0       39.0        0.0              1.0
# totalvehs        0.994552   1728.0    23412.0        0.0              1.0
# wdhhwgt               NaN      NaN        NaN        NaN              NaN
# wehhwgt               NaN      NaN        NaN        NaN              NaN
# homelga               NaN      NaN        NaN        NaN              NaN
# homesubregion         NaN      NaN        NaN        NaN              NaN
# homeregion            NaN      NaN        NaN        NaN              NaN
# homepc         271.669229      0.0    25140.0        0.0           3002.0
# cars_cat              NaN      NaN        NaN        NaN              NaN
#
#                nonzero_maximum  nonzero_mean  nonzero_stdev  nulls mode
# hhid                       NaN           NaN            NaN    NaN  NaN
# surveyperiod               NaN           NaN            NaN    NaN  NaN
# travdow                    NaN           NaN            NaN    NaN  NaN
# travmonth                  NaN           NaN            NaN    NaN  NaN
# daytype                    NaN           NaN            NaN    NaN  NaN
# dwelltype                  NaN           NaN            NaN    NaN  NaN
# owndwell                   NaN           NaN            NaN    NaN  NaN
# hhsize                    11.0      2.566269       1.323591    NaN  NaN
# hhinc                      NaN           NaN            NaN    NaN  NaN
# visitors                  12.0      2.020435       1.300679    NaN  NaN
# aveage                  1928.0     45.383930      23.779781    NaN  NaN
# youngest                1927.0     37.599066      28.231282    NaN  NaN
# oldest                  1929.0     54.539141      23.042031    NaN  NaN
# yearslived                88.0     14.039595      13.392221    NaN  NaN
# monthslived               18.0      5.115577       2.622850    NaN  NaN
# adultbikes                15.0      1.956533       1.143320    NaN  NaN
# kidsbikes                 11.0      1.862666       0.981275    NaN  NaN
# totalbikes                15.0      2.494450       1.588734    NaN  NaN
# cars                       8.0      1.540031       0.751726    NaN  NaN
# fourwds                    5.0      1.142725       0.375657    NaN  NaN
# utes                       4.0      1.059214       0.254091    NaN  NaN
# vans                       2.0      1.039841       0.195585    NaN  NaN
# trucks                     4.0      1.055556       0.306816    NaN  NaN
# mbikes                     5.0      1.200000       0.512901    NaN  NaN
# othervehs                  1.0      1.000000       0.000000    NaN  NaN
# totalvehs                  9.0      1.843371       0.910262    NaN  NaN
# wdhhwgt                    NaN           NaN            NaN    NaN  NaN
# wehhwgt                    NaN           NaN            NaN    NaN  NaN
# homelga                    NaN           NaN            NaN    NaN  NaN
# homesubregion              NaN           NaN            NaN    NaN  NaN
# homeregion                 NaN           NaN            NaN    NaN  NaN
# homepc                  3981.0   3230.606523     271.669229    NaN  NaN
# cars_cat                   NaN           NaN            NaN    0.0    1

# %%
# prepare choice model data
hhauto = (
    households
        .filter(['hhid', 'cars_cat', 'dwelltype', 'hhsize', 'hhinc', 'owndwell'])
        .assign(
            # integerise household income (hhinc)
            hhinc = lambda x: x.hhinc.str.strip().str.replace(r'\$|,', '').str.replace('^$', '0').astype(int),
            owndwell = lambda x: x.owndwell.astype('category'),
            dwelltype = lambda x: x.dwelltype.astype('category')
        )
)

hhauto.statistics()
# Out:
# /var/folders/0r/_nfqg0v10sq4lf56q9dr_pz80000gn/T/ipykernel_2413/623732550.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   hhinc = lambda x: x.hhinc.str.strip().str.replace(r'\$|,', '').str.replace('^$', '0').astype(int),
#                n                                          histogram  nulls  \
# hhid       25140                                                NaN    NaN
# cars_cat   25140  [[[<Element '{http://www.w3.org/1999/02/22-rdf...    0.0
# dwelltype  25140  [[[<Element '{http://www.w3.org/1999/02/22-rdf...    0.0
# hhsize     25140  [[[<Element '{http://www.w3.org/1999/02/22-rdf...    NaN
# hhinc      25140  [[[<Element '{http://www.w3.org/1999/02/22-rdf...    NaN
# owndwell   25140  [[[<Element '{http://www.w3.org/1999/02/22-rdf...    0.0
#
#                      mode  minimum  maximum  median         mean        stdev  \
# hhid                  NaN      NaN      NaN     NaN          NaN          NaN
# cars_cat                1      NaN      NaN     NaN          NaN          NaN
# dwelltype  Separate House      NaN      NaN     NaN          NaN          NaN
# hhsize                NaN      1.0     11.0     2.0     2.566269     1.323591
# hhinc                 NaN      0.0  12500.0  1725.0  1907.286197  1331.079174
# owndwell      Fully Owned      NaN      NaN     NaN          NaN          NaN
#
#            zeros  positives  negatives  nonzero_minimum  nonzero_maximum  \
# hhid         NaN        NaN        NaN              NaN              NaN
# cars_cat     NaN        NaN        NaN              NaN              NaN
# dwelltype    NaN        NaN        NaN              NaN              NaN
# hhsize       0.0    25140.0        0.0              1.0             11.0
# hhinc      468.0    24672.0        0.0            100.0          12500.0
# owndwell     NaN        NaN        NaN              NaN              NaN
#
#            nonzero_mean  nonzero_stdev
# hhid                NaN            NaN
# cars_cat            NaN            NaN
# dwelltype           NaN            NaN
# hhsize         2.566269       1.323591
# hhinc       1943.465264    1317.219617
# owndwell            NaN            NaN

# %% [markdown]
# ## Prepare choice data
#
# {larch} requires the choice data to be in a specific format.

# %%
df = (
    hhauto
     .filter(['hhid'])
     .merge(pd.DataFrame({'cars_choice': ['0', '1', '2', '3+']}), how='cross')
     .merge(hhauto, on = ['hhid'])
     .rename(columns={'cars_cat': 'cars'})
     .assign(cars_chosen = lambda x: np.where(x.cars == x.cars_choice, 1, 0))
     .drop(['cars'], axis = 1)
     .assign(hhid = lambda x: x.groupby(['hhid']).ngroup()+1)
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100560 entries, 0 to 100559
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   hhid         100560 non-null  int64
#  1   cars_choice  100560 non-null  object
#  2   dwelltype    100560 non-null  category
#  3   hhsize       100560 non-null  int64
#  4   hhinc        100560 non-null  int64
#  5   owndwell     100560 non-null  category
#  6   cars_chosen  100560 non-null  int64
# dtypes: category(2), int64(4), object(1)
# memory usage: 4.8+ MB

# %% [markdown]
# Problems to be addressed
# - `alt_codes` and `alt_names` cannot be specified.
# - m.

# %%
d = lx.DataFrames(
    df.set_index(['hhid', 'cars_choice']),
    ch='cars_chosen',
    crack=True,
    # alt_codes=[0,1,2,3],
    # alt_names=['a','b','c'],
    av=True
    # alt_names=['a', 'b', 'c'],
    # alt_codes=[1, 2, 3]
)
d.info(verbose=True)
d.alternative_names()
# Out:
# converting data_ch to <class 'numpy.float64'>
# larch.DataFrames:  (not computation-ready)
#   n_cases: 25140
#   n_alts: 4
#   data_ca:
#     - dwelltype   (100560 non-null category)
#     - owndwell    (100560 non-null category)
#     - cars_chosen (100560 non-null int64)
#   data_co:
#     - hhsize (25140 non-null int64)
#     - hhinc  (25140 non-null int64)
#   data_av: <populated>
#   data_ch: cars_chosen
# ['0', '1', '2', '3+']

# %% [markdown]
# ## Estimate a driver's licence status model
#
# Using the persons table and larch, we estimate a MNL model for predicting the probabilities of driver's licence status.

# %%
m = lx.Model(dataservice=d)
m.utility_co[1] = P("ASC_1") + P("hhinc#2") * X("hhinc") + P("hhsize#2") * X("hhsize")
m.utility_co[2] = P("ASC_2") + P("hhinc#3") * X("hhinc") + P("hhsize#3") * X("hhsize")
m.utility_co[3] = P("ASC_3+") + P("hhinc#4") * X("hhinc") + P("hhsize#4") * X("hhsize")
# m.utility_co[4] = P("ASC_4+") + P("hhinc#5") * X("hhinc") + P("hhsize#5") * X("hhsize")
# m.utility_ca = PX("x2")
m.estimate()
m.parameter_summary()
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# <h3>Iteration 009 [Optimization terminated successfully.] </h3>
# <p>Best LL = -28424.38636618144</p>
#              value  initvalue  nullvalue  minimum  maximum  holdfast note  \
# ASC_1     3.988670        0.0        0.0     -inf      inf         0
# ASC_2     4.786766        0.0        0.0     -inf      inf         0
# ASC_3+    2.914152        0.0        0.0     -inf      inf         0
# hhinc#2  -0.000454        0.0        0.0     -inf      inf         0
# hhinc#3  -0.000384        0.0        0.0     -inf      inf         0
# hhinc#4  -0.000202        0.0        0.0     -inf      inf         0
# hhsize#2 -0.759856        0.0        0.0     -inf      inf         0
# hhsize#3 -0.702653        0.0        0.0     -inf      inf         0
# hhsize#4 -0.351632        0.0        0.0     -inf      inf         0
#
#               best
# ASC_1     3.988670
# ASC_2     4.786766
# ASC_3+    2.914152
# hhinc#2  -0.000454
# hhinc#3  -0.000384
# hhinc#4  -0.000202
# hhsize#2 -0.759856
# hhsize#3 -0.702653
# hhsize#4 -0.351632
# <style type="text/css">
# #T_ca410 th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_ca410 td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_ca410_row0_col0, #T_ca410_row0_col1, #T_ca410_row0_col2, #T_ca410_row0_col3, #T_ca410_row0_col4, #T_ca410_row1_col0, #T_ca410_row1_col1, #T_ca410_row1_col2, #T_ca410_row1_col3, #T_ca410_row1_col4, #T_ca410_row2_col0, #T_ca410_row2_col1, #T_ca410_row2_col2, #T_ca410_row2_col3, #T_ca410_row2_col4, #T_ca410_row3_col0, #T_ca410_row3_col1, #T_ca410_row3_col2, #T_ca410_row3_col3, #T_ca410_row3_col4, #T_ca410_row4_col0, #T_ca410_row4_col1, #T_ca410_row4_col2, #T_ca410_row4_col3, #T_ca410_row4_col4, #T_ca410_row5_col0, #T_ca410_row5_col1, #T_ca410_row5_col2, #T_ca410_row5_col3, #T_ca410_row5_col4, #T_ca410_row6_col0, #T_ca410_row6_col1, #T_ca410_row6_col2, #T_ca410_row6_col3, #T_ca410_row6_col4, #T_ca410_row7_col0, #T_ca410_row7_col1, #T_ca410_row7_col2, #T_ca410_row7_col3, #T_ca410_row7_col4, #T_ca410_row8_col0, #T_ca410_row8_col1, #T_ca410_row8_col2, #T_ca410_row8_col3, #T_ca410_row8_col4 {
#   font-family: monospace;
# }
# </style>
# <table id="T_ca410">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca410_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_ca410_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_ca410_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_ca410_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_ca410_level0_col4" class="col_heading level0 col4" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca410_level0_row0" class="row_heading level0 row0" >ASC_1</th>
#       <td id="T_ca410_row0_col0" class="data row0 col0" > 3.99</td>
#       <td id="T_ca410_row0_col1" class="data row0 col1" > 0.0830</td>
#       <td id="T_ca410_row0_col2" class="data row0 col2" > 48.06</td>
#       <td id="T_ca410_row0_col3" class="data row0 col3" >***</td>
#       <td id="T_ca410_row0_col4" class="data row0 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row1" class="row_heading level0 row1" >ASC_2</th>
#       <td id="T_ca410_row1_col0" class="data row1 col0" > 4.79</td>
#       <td id="T_ca410_row1_col1" class="data row1 col1" > 0.0779</td>
#       <td id="T_ca410_row1_col2" class="data row1 col2" > 61.45</td>
#       <td id="T_ca410_row1_col3" class="data row1 col3" >***</td>
#       <td id="T_ca410_row1_col4" class="data row1 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row2" class="row_heading level0 row2" >ASC_3+</th>
#       <td id="T_ca410_row2_col0" class="data row2 col0" > 2.91</td>
#       <td id="T_ca410_row2_col1" class="data row2 col1" > 0.0786</td>
#       <td id="T_ca410_row2_col2" class="data row2 col2" > 37.09</td>
#       <td id="T_ca410_row2_col3" class="data row2 col3" >***</td>
#       <td id="T_ca410_row2_col4" class="data row2 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row3" class="row_heading level0 row3" >hhinc#2</th>
#       <td id="T_ca410_row3_col0" class="data row3 col0" >-0.000454</td>
#       <td id="T_ca410_row3_col1" class="data row3 col1" > 2.26e-05</td>
#       <td id="T_ca410_row3_col2" class="data row3 col2" >-20.06</td>
#       <td id="T_ca410_row3_col3" class="data row3 col3" >***</td>
#       <td id="T_ca410_row3_col4" class="data row3 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row4" class="row_heading level0 row4" >hhinc#3</th>
#       <td id="T_ca410_row4_col0" class="data row4 col0" >-0.000384</td>
#       <td id="T_ca410_row4_col1" class="data row4 col1" > 1.87e-05</td>
#       <td id="T_ca410_row4_col2" class="data row4 col2" >-20.57</td>
#       <td id="T_ca410_row4_col3" class="data row4 col3" >***</td>
#       <td id="T_ca410_row4_col4" class="data row4 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row5" class="row_heading level0 row5" >hhinc#4</th>
#       <td id="T_ca410_row5_col0" class="data row5 col0" >-0.000202</td>
#       <td id="T_ca410_row5_col1" class="data row5 col1" > 1.81e-05</td>
#       <td id="T_ca410_row5_col2" class="data row5 col2" >-11.12</td>
#       <td id="T_ca410_row5_col3" class="data row5 col3" >***</td>
#       <td id="T_ca410_row5_col4" class="data row5 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row6" class="row_heading level0 row6" >hhsize#2</th>
#       <td id="T_ca410_row6_col0" class="data row6 col0" >-0.760</td>
#       <td id="T_ca410_row6_col1" class="data row6 col1" > 0.0239</td>
#       <td id="T_ca410_row6_col2" class="data row6 col2" >-31.78</td>
#       <td id="T_ca410_row6_col3" class="data row6 col3" >***</td>
#       <td id="T_ca410_row6_col4" class="data row6 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row7" class="row_heading level0 row7" >hhsize#3</th>
#       <td id="T_ca410_row7_col0" class="data row7 col0" >-0.703</td>
#       <td id="T_ca410_row7_col1" class="data row7 col1" > 0.0202</td>
#       <td id="T_ca410_row7_col2" class="data row7 col2" >-34.72</td>
#       <td id="T_ca410_row7_col3" class="data row7 col3" >***</td>
#       <td id="T_ca410_row7_col4" class="data row7 col4" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ca410_level0_row8" class="row_heading level0 row8" >hhsize#4</th>
#       <td id="T_ca410_row8_col0" class="data row8 col0" >-0.352</td>
#       <td id="T_ca410_row8_col1" class="data row8 col1" > 0.0198</td>
#       <td id="T_ca410_row8_col2" class="data row8 col2" >-17.78</td>
#       <td id="T_ca410_row8_col3" class="data row8 col3" >***</td>
#       <td id="T_ca410_row8_col4" class="data row8 col4" > 0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## A minimal example of Larch with on a dummy dataset

# %%
test_df = (pd.DataFrame({
    'caseid': [1, 1, 1, 2, 2, 2],
    'altid': ['a', 'b', 'c', 'a', 'b', 'c'],
    'chose': [1, 0, 0, 0, 1, 0],
    'x1': [500, 500, 500, 2000, 2000, 2000],
    'x2': [123, 322, 435, 123, 435, 234],
    'x_av': [1, 1, 0, 1, 1, 1],
}).assign(altid = lambda x: x.altid.astype('category'))
      )

# test_df.reset_index().info()

# %%
# ds = lx.Dataset.construct.from_idca(test_df.set_index(['caseid', 'altid']))
# m = lx.Model(ds)
# m.choice_ca_code = 'cars_cat'
# ds

d = lx.DataFrames(
    test_df.set_index(['caseid', 'altid']),
    ch='chose',
    crack=True,
    # alt_codes=[1,2,3],
    # alt_names=['a','b','c'],
    av='x_av == 1'
    # alt_names=['a', 'b', 'c'],
    # alt_codes=[1, 2, 3]
)
d.info(verbose=True)
d.alternative_names()
# Out:
# converting data_ch to <class 'numpy.float64'>
# larch.DataFrames:  (not computation-ready)
#   n_cases: 2
#   n_alts: 3
#   data_ca:
#     - chose (6 non-null int64)
#     - x2    (6 non-null int64)
#     - x_av  (6 non-null int64)
#   data_co:
#     - x1 (2 non-null int64)
#   data_av: x_av == 1
#   data_ch: chose
# ['a', 'b', 'c']

# %%
# d.data_co.statistics()
m = lx.Model(dataservice=d)

# %%
from larch import P, X, PX

# %%
m.utility_co[2] = P("ASC_b")  + P("x1#2") * X("x1")
m.utility_co[3] = P("ASC_c") + P("x1#3") * X("x1")
m.utility_ca = PX("x2")
m.estimate()
m.parameter_summary()
# Out:
# req_data does not request {choice_ca,choice_co,choice_co_code} but choice is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_ca to <class 'numpy.float64'>
# converting data_co to <class 'numpy.float64'>
# <h3>Iteration 019 [Optimization terminated successfully.] </h3>
# <p>Best LL = -2.842170943040401e-14</p>
#                value  initvalue  nullvalue  minimum  maximum  holdfast note  \
# ASC_b       1.320741        0.0        0.0     -inf      inf         0
# ASC_c  455870.090751        0.0        0.0     -inf      inf         0
# x1#2        0.152631        0.0        0.0     -inf      inf         0
# x1#3     -519.650844        0.0        0.0     -inf      inf         0
# x2         -0.883112        0.0        0.0     -inf      inf         0
#
#                 best
# ASC_b       1.320741
# ASC_c  455870.090751
# x1#2        0.152631
# x1#3     -519.650844
# x2         -0.883112
# /opt/homebrew/Caskroom/mambaforge/base/envs/actsim-melb/lib/python3.9/site-packages/larch/linalg/__init__.py:18: UserWarning: minimum eig 0.0 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# <style type="text/css">
# #T_1be8a th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1be8a td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1be8a_row0_col0, #T_1be8a_row0_col1, #T_1be8a_row0_col2, #T_1be8a_row0_col3, #T_1be8a_row0_col4, #T_1be8a_row0_col5, #T_1be8a_row1_col0, #T_1be8a_row1_col1, #T_1be8a_row1_col2, #T_1be8a_row1_col3, #T_1be8a_row1_col4, #T_1be8a_row1_col5, #T_1be8a_row2_col0, #T_1be8a_row2_col1, #T_1be8a_row2_col2, #T_1be8a_row2_col3, #T_1be8a_row2_col4, #T_1be8a_row2_col5, #T_1be8a_row3_col0, #T_1be8a_row3_col1, #T_1be8a_row3_col2, #T_1be8a_row3_col3, #T_1be8a_row3_col4, #T_1be8a_row3_col5, #T_1be8a_row4_col0, #T_1be8a_row4_col1, #T_1be8a_row4_col2, #T_1be8a_row4_col3, #T_1be8a_row4_col4, #T_1be8a_row4_col5 {
#   font-family: monospace;
# }
# </style>
# <table id="T_1be8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1be8a_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_1be8a_level0_col1" class="col_heading level0 col1" >Std Err</th>
#       <th id="T_1be8a_level0_col2" class="col_heading level0 col2" >t Stat</th>
#       <th id="T_1be8a_level0_col3" class="col_heading level0 col3" >Signif</th>
#       <th id="T_1be8a_level0_col4" class="col_heading level0 col4" >Like Ratio</th>
#       <th id="T_1be8a_level0_col5" class="col_heading level0 col5" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1be8a_level0_row0" class="row_heading level0 row0" >ASC_b</th>
#       <td id="T_1be8a_row0_col0" class="data row0 col0" > 1.32</td>
#       <td id="T_1be8a_row0_col1" class="data row0 col1" > 0.00</td>
#       <td id="T_1be8a_row0_col2" class="data row0 col2" > NA</td>
#       <td id="T_1be8a_row0_col3" class="data row0 col3" >[]</td>
#       <td id="T_1be8a_row0_col4" class="data row0 col4" > 0.00</td>
#       <td id="T_1be8a_row0_col5" class="data row0 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row1" class="row_heading level0 row1" >ASC_c</th>
#       <td id="T_1be8a_row1_col0" class="data row1 col0" > 4.56e+05</td>
#       <td id="T_1be8a_row1_col1" class="data row1 col1" > 0.00</td>
#       <td id="T_1be8a_row1_col2" class="data row1 col2" > NA</td>
#       <td id="T_1be8a_row1_col3" class="data row1 col3" >[]</td>
#       <td id="T_1be8a_row1_col4" class="data row1 col4" > 0.00</td>
#       <td id="T_1be8a_row1_col5" class="data row1 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row2" class="row_heading level0 row2" >x1#2</th>
#       <td id="T_1be8a_row2_col0" class="data row2 col0" > 0.153</td>
#       <td id="T_1be8a_row2_col1" class="data row2 col1" > 0.00</td>
#       <td id="T_1be8a_row2_col2" class="data row2 col2" > NA</td>
#       <td id="T_1be8a_row2_col3" class="data row2 col3" >[***]</td>
#       <td id="T_1be8a_row2_col4" class="data row2 col4" > 274.21</td>
#       <td id="T_1be8a_row2_col5" class="data row2 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row3" class="row_heading level0 row3" >x1#3</th>
#       <td id="T_1be8a_row3_col0" class="data row3 col0" >-520.</td>
#       <td id="T_1be8a_row3_col1" class="data row3 col1" > 0.00</td>
#       <td id="T_1be8a_row3_col2" class="data row3 col2" > NA</td>
#       <td id="T_1be8a_row3_col3" class="data row3 col3" >[***]</td>
#       <td id="T_1be8a_row3_col4" class="data row3 col4" > BIG</td>
#       <td id="T_1be8a_row3_col5" class="data row3 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1be8a_level0_row4" class="row_heading level0 row4" >x2</th>
#       <td id="T_1be8a_row4_col0" class="data row4 col0" >-0.883</td>
#       <td id="T_1be8a_row4_col1" class="data row4 col1" > 0.00</td>
#       <td id="T_1be8a_row4_col2" class="data row4 col2" > NA</td>
#       <td id="T_1be8a_row4_col3" class="data row4 col3" >[***]</td>
#       <td id="T_1be8a_row4_col4" class="data row4 col4" > 77.64</td>
#       <td id="T_1be8a_row4_col5" class="data row4 col5" > 0.00</td>
#     </tr>
#   </tbody>
# </table>
